# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("wayfair_uniq.csv")  
df_new=df.iloc[:,[3,4,5,7,9,11,13,15,17,18,19]]
df_new['index'] = df_new.index
df_new.shape

df_new.head()


df_new['original_price'] = df_new.original_price.str.replace('$', '')
df_new['original_price'] = df_new.original_price.str.replace(',', '').astype(float)

new_price = df_new["price"].str.split(";\s\$", n = 1, expand = True)
df_new["new_price"] = new_price[1]
df_new.drop(columns =["price"], inplace = True)


price_range = df_new[df_new["new_price"].str.contains("-",regex=True)]
price_range['new_price'] = (price_range['new_price'].str.split("\s-", n = 1, expand = True))[0]
df_new.loc[price_range.index] = price_range
df_new['new_price'] = df_new.new_price.str.replace(',', '').astype(float)


bins = [0,500,1000,1500,2000,2500,3000,3500,4000,4500,35000]
labels = ["<$500","$500-$1000","$1000-$1500","$1500-$2000","$2000-$2500","$2500-$3000","$3000-$3500","$3500-$4000","$4000-$4500",">$4500"]
df_new['price_bracket'] = pd.cut(df_new['new_price'], bins, labels=labels)


features = ["product_data1","product_data2","product_descrip","manufacturer"]


for feature in features:
      df_new[feature] = df_new[feature].fillna('')

def combine_features(row):
      try:
         return row['product_data1'] +" "+row['product_data2']+" "+row["product_descrip"]+" "+row["price_bracket"]+" "+row["manufacturer"]
      except:
         print("Error:", row)
    
df_new["combined_features"] = df_new.apply(combine_features,axis=1)


stop_words = stopwords.words('english')
df_new['combined_features'] = df_new['combined_features'].str.lower().str.split()
df_new["features"]=df_new["combined_features"].apply(lambda x: [word for word in x if word not in stop_words])
df_new["features"]=df_new["features"].apply(lambda x: " ".join(x))

cv = CountVectorizer()
count_matrix = cv.fit_transform(df_new["features"])

cosine_sim = cosine_similarity(count_matrix)



def get_title_from_index(index):
    return df_new[df_new.index == index]["product_name"].values[0]

def get_home(index):
    return df_new[df_new.index == index]["product_name_link"].values[0]

def get_index_from_title(title):
    return df_new[df_new.product_name == title]["index"].values[0]

product_user_likes = 'Rosalie Sofa'
product_index = get_index_from_title(product_user_likes)

similar_products =  list(enumerate(cosine_sim[product_index]))

sorted_similar_products = sorted(similar_products,key=lambda x:x[1],reverse=True)

i=0
for element in sorted_similar_products:
    print (get_title_from_index(element[0]),get_home(element[0]))
    i=i+1
    if i>50:
        break
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
# (17209, 12)
#                                 product_name  \
# 0               Ariana 63" Column Floor Lamp
# 1          Dale 63.75" Arched/Arc Floor Lamp
# 2  Carlisle Douthit 70" Swing Arm Floor Lamp
# 3                Morrill 82" Tree Floor Lamp
# 4   Shipton Crystal and Metal 61" Floor Lamp
#
#                                    product_name_link             manufacturer  \
# 0  https://www.wayfair.com/lighting/pdp/zipcode-d...        by Zipcode Design
# 1  https://www.wayfair.com/v/wayup/sponsored_skus...        by Langley Street
# 2  https://www.wayfair.com/lighting/pdp/williston...       by Williston Forge
# 3  https://www.wayfair.com/lighting/pdp/brayden-s...        by Brayden Studio
# 4  https://www.wayfair.com/lighting/pdp/willa-arl...  by Willa Arlo Interiors
#
#                    price original_price  review_count  \
# 0    from $38.02; $38.02        $69.99         3878.0
# 1         $73.99; $73.99        $99.99         1382.0
# 2  from $104.99; $104.99       $399.99         1084.0
# 3       $143.99; $143.99       $230.00         3476.0
# 4         $62.99; $62.99       $170.04         2099.0
#
#                                   review_data        shipping_time  \
# 0  Rated 4.5 out of 5 stars.3878 total votes.                  NaN
# 1  Rated 4.5 out of 5 stars.1382 total votes.  FREE 2-Day Shipping
# 2  Rated 4.5 out of 5 stars.1084 total votes.  FREE 2-Day Shipping
# 3  Rated 4.5 out of 5 stars.3476 total votes.  FREE 2-Day Shipping
# 4  Rated 4.5 out of 5 stars.2099 total votes.  FREE 2-Day Shipping
#
#                                      product_descrip  \
# 0  Short on space? Make the most of your square f...
# 1  With a slender silhouette, this floor lamp bri...
# 2  Part decor and part luminary, we love floor la...
# 3  When your ensemble is in need of a little illu...
# 4  Equally alluring sitting sofa-side for a littl...
#
#                 product_data1                         product_data2  index
# 0  Switch Type: On/Off switch                                   NaN      0
# 1    Switch Type: Foot Switch  Maximum Wattage (per Bulb): 100 Watt      1
# 2  Switch Type: Rotary socket  Maximum Wattage (per Bulb): 100 Watt      2
# 3          Switch Type: 4-Way   Maximum Wattage (per Bulb): 26 Watt      3
# 4  Switch Type: On/Off switch   Maximum Wattage (per Bulb): 60 Watt      4
# Rosalie Sofa https://www.wayfair.com/furniture/pdp/rosalie-sofa-lrfy2382.html
# Rosalie Loveseat https://www.wayfair.com/furniture/pdp/rosalie-loveseat-lrfy2381.html
# Lauryn Sofa https://www.wayfair.com/furniture/pdp/lauryn-sofa-w001370014.html
# Zander Tufted Sofa https://www.wayfair.com/furniture/pdp/orren-ellis-zander-tufted-sofa-orel4706.html
# Marbleton Sofa https://www.wayfair.com/furniture/pdp/loon-peak-marbleton-sofa-loon1825.html
# Grosvenor Chesterfield Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-grosvenor-chesterfield-sofa-wrlo1738.html
# Logan 3 Seater Sofa https://www.wayfair.com/furniture/pdp/brayden-studio-logan-3-seater-sofa-brys2211.html
# Shullsburg Reclining Sofa https://www.wayfair.com/furniture/pdp/winston-porter-shullsburg-reclining-sofa-w001517407.html
# Chisolm Loveseat https://www.wayfair.com/furniture/pdp/charlton-home-chisolm-loveseat-chlh6419.html
# Cecilia Sofa https://www.wayfair.com/furniture/pdp/beverly-fine-furniture-cecilia-sofa-qrmg1038.html
# Bora Loveseat https://www.wayfair.com/furniture/pdp/latitude-run-bora-loveseat-ltrn1466.html
# Lena Sofa https://www.wayfair.com/furniture/pdp/beverly-fine-furniture-lena-sofa-qrmg1031.html
# Hartell Chesterfield Sofa https://www.wayfair.com/furniture/pdp/mistana-hartell-chesterfield-sofa-mtna4110.html
# Bora Sofa https://www.wayfair.com/furniture/pdp/latitude-run-bora-sofa-ltrn1465.html
# Meggie Sofa https://www.wayfair.com/furniture/pdp/langley-street-meggie-sofa-lgly5865.html
# Kulick Loveseat https://www.wayfair.com/furniture/pdp/house-of-hampton-kulick-loveseat-hmpt2842.html
# Simmons Upholstery Hattiesburg Stone Sofa https://www.wayfair.com/furniture/pdp/three-posts-simmons-upholstery-hattiesburg-stone-sofa-trpt4039.html
# Serta Upholstery Loveseat https://www.wayfair.com/furniture/pdp/serta-upholstery-loveseat-xsq1417.html
# Marlborough Sofa https://www.wayfair.com/furniture/pdp/serta-upholstery-marlborough-sofa-xsq1848.html
# Kinnas Sofa https://www.wayfair.com/furniture/pdp/red-barrel-studio-kinnas-sofa-rdba1167.html
# Danette Elegant Classic Chesterfield Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-danette-elegant-classic-chesterfield-sofa-wlao2807.html
# Rogich Sofa https://www.wayfair.com/furniture/pdp/latitude-run-rogich-sofa-xtbg1115.html
# Izzie Chesterfield Sofa https://www.wayfair.com/furniture/pdp/everly-quinn-izzie-chesterfield-sofa-eyqn7773.html
# Rathdowney Simmons Sofa Bed https://www.wayfair.com/furniture/pdp/alcott-hill-rathdowney-simmons-sofa-bed-alct4633.html
# Kizer Contemporary Sofa https://www.wayfair.com/furniture/pdp/everly-quinn-kizer-contemporary-sofa-eyqn6808.html
# Callis Sofa https://www.wayfair.com/furniture/pdp/george-oliver-callis-sofa-w001074062.html
# Morgana Sofa https://www.wayfair.com/furniture/pdp/langley-street-morgana-sofa-lgly4830.html
# Garrow Microfiber Convertible Sofa https://www.wayfair.com/furniture/pdp/red-barrel-studio-garrow-microfiber-convertible-sofa-rdbe2362.html
# Nancy Sofa https://www.wayfair.com/furniture/pdp/red-barrel-studio-nancy-sofa-rdbt3370.html
# Meisner Standard Sofa https://www.wayfair.com/furniture/pdp/red-barrel-studio-meisner-standard-sofa-rdbe2951.html
# Ophir Upholstery Loveseat https://www.wayfair.com/furniture/pdp/alcott-hill-ophir-upholstery-loveseat-w001671221.html
# Elienor Arms Sofa by Simmons Upholstery https://www.wayfair.com/furniture/pdp/world-menagerie-elienor-arms-sofa-by-simmons-upholstery-wrmg3042.html
# Dilorenzo Object Sofa https://www.wayfair.com/furniture/pdp/latitude-run-dilorenzo-object-sofa-lder8625.html
# Ayawovi Sofa https://www.wayfair.com/furniture/pdp/red-barrel-studio-ayawovi-sofa-rdba2298.html
# Dia Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-dia-sofa-wrlo6820.html
# 3 Seater Big Sofa https://www.wayfair.com/furniture/pdp/beliani-3-seater-big-sofa-aaje1011.html
# Stewartsville Leather Sofa https://www.wayfair.com/furniture/pdp/fleur-de-lis-living-stewartsville-leather-sofa-w001384305.html
# Popovich Reclining Sofa https://www.wayfair.com/furniture/pdp/winston-porter-popovich-reclining-sofa-wnst4570.html
# Sitara Sofa https://www.wayfair.com/furniture/pdp/rez-furniture-sitara-sofa-rezf1046.html
# Hitton Tufted Sofa https://www.wayfair.com/furniture/pdp/corrigan-studio-hitton-tufted-sofa-w001145598.html
# Zurich Chesterfield Loveseat https://www.wayfair.com/furniture/pdp/florida-seating-zurich-chesterfield-loveseat-flri2182.html
# Cambridge Sofa https://www.wayfair.com/furniture/pdp/klaussner-furniture-cambridge-sofa-klf3845.html
# Vianna Chesterfield Sofa https://www.wayfair.com/furniture/pdp/willa-arlo-interiors-vianna-chesterfield-sofa-wrlo8071.html
# Elsa Sofa https://www.wayfair.com/furniture/pdp/beverly-fine-furniture-elsa-sofa-qrmg1147.html
# Ace Sofa https://www.wayfair.com/furniture/pdp/beverly-fine-furniture-ace-sofa-qrmg1152.html
# Wilborn Loveseat https://www.wayfair.com/furniture/pdp/winston-porter-wilborn-loveseat-wnsp6028.html
# Eyota Sofa https://www.wayfair.com/furniture/pdp/ebern-designs-eyota-sofa-w001265669.html
# Dorothy Loveseat https://www.wayfair.com/furniture/pdp/darby-home-co-dorothy-loveseat-drbh8025.html
# Waldrup Sofa https://www.wayfair.com/furniture/pdp/charlton-home-waldrup-sofa-w001678810.html
# Ringold Sofa https://www.wayfair.com/furniture/pdp/brayden-studio-ringold-sofa-w000103232.html
# Loveseat https://www.wayfair.com/furniture/pdp/serta-upholstery-loveseat-xsq1778.html
